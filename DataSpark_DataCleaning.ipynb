# %%
##-Data collection
import pandas as pd

# %%
#1.Customers.csv
import pandas as pd
try:
    df1 = pd.read_csv('/Customers.csv', encoding='utf-8')
except UnicodeDecodeError:
    df1 = pd.read_csv('/Customers.csv', encoding='latin1')

# %%
df1.head()
# Out:
#    CustomerKey  Gender               Name            City State Code  \
# 0          301  Female      Lilly Harding  WANDEARAH EAST         SA
# 1          325  Female       Madison Hull      MOUNT BUDD         WA
# 2          554  Female      Claire Ferres       WINJALLOK        VIC
# 3          786    Male  Jai Poltpalingada    MIDDLE RIVER         SA
# 4         1042    Male    Aidan Pankhurst   TAWONGA SOUTH        VIC
#
#                State Zip Code    Country  Continent    Birthday
# 0    South Australia     5523  Australia  Australia    7/3/1939
# 1  Western Australia     6522  Australia  Australia   9/27/1979
# 2           Victoria     3380  Australia  Australia   5/26/1947
# 3    South Australia     5223  Australia  Australia   9/17/1957
# 4           Victoria     3698  Australia  Australia  11/19/1965

# %%
##-Data preparation:
df1.shape
# Out:
# (15266, 10)

# %%
# Check for missing values
df1.isnull().sum()
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
# Remove rows with missing values in the rating_count column
df1.dropna(subset=['State Code'], inplace=True)
df1.isnull().sum()
# Out:
# CustomerKey    0
# Gender         0
# Name           0
# City           0
# State Code     0
# State          0
# Zip Code       0
# Country        0
# Continent      0
# Birthday       0
# dtype: int64

# %%
# Check for duplicates
df1.duplicated().sum()
# Out:
# 0

# %%
# Check data types
df1.dtypes
# Out:
# CustomerKey     int64
# Gender         object
# Name           object
# City           object
# State Code     object
# State          object
# Zip Code       object
# Country        object
# Continent      object
# Birthday       object
# dtype: object

# %%
# Convert 'Birthday' to datetime:
#Using errors=’coerce’. It will replace values with NaN.
df1['Birthday']= pd.to_datetime(df1['Birthday'], errors='coerce')

# %%
# Check data types
df1.dtypes
# Out:
# CustomerKey             int64
# Gender                 object
# Name                   object
# City                   object
# State Code             object
# State                  object
# Zip Code               object
# Country                object
# Continent              object
# Birthday       datetime64[ns]
# dtype: object

# %%
df1.to_csv('customer1.csv',index=False)

# %%
pd.read_csv('customer1.csv')
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15251      2099600  Female     Denisa Duková              Houston         TX
# 15252      2099618    Male   Justin Solórzano               Mclean         VA
# 15253      2099758    Male    Svend Petrussen           Wilmington         NC
# 15254      2099862  Female       Lorenza Rush            Riverside         CA
# 15255      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
#2.Exchange_Rates
import pandas as pd
try:
    df2 = pd.read_csv('/Exchange_Rates.csv', encoding='utf-8')
except UnicodeDecodeError:
    df2 = pd.read_csv('/Exchange_Rates.csv', encoding='latin1')

# %%
df2.head()
# Out:
#        Date Currency  Exchange
# 0  1/1/2015      USD    1.0000
# 1  1/1/2015      CAD    1.1583
# 2  1/1/2015      AUD    1.2214
# 3  1/1/2015      EUR    0.8237
# 4  1/1/2015      GBP    0.6415

# %%
#2-Data preparation:
df2.shape
# Out:
# (11215, 3)

# %%
# Check for missing values
df2.isnull().sum()
# Out:
# Date        0
# Currency    0
# Exchange    0
# dtype: int64

# %%
# Check for duplicates
df2.duplicated().sum()
# Out:
# 0

# %%
# Check data types
df2.dtypes
# Out:
# Date         object
# Currency     object
# Exchange    float64
# dtype: object

# %%
# Convert 'Date' to datetime:
#Using errors=’coerce’. It will replace values with NaN.
df2['Date']= pd.to_datetime(df2['Date'], errors='coerce')

# %%
df2.to_csv('Exchange_Rates1.csv',index=False)

# %%
pd.read_csv('Exchange_Rates1.csv')
# Out:
#              Date Currency  Exchange
# 0      2015-01-01      USD    1.0000
# 1      2015-01-01      CAD    1.1583
# 2      2015-01-01      AUD    1.2214
# 3      2015-01-01      EUR    0.8237
# 4      2015-01-01      GBP    0.6415
# ...           ...      ...       ...
# 11210  2021-02-20      USD    1.0000
# 11211  2021-02-20      CAD    1.2610
# 11212  2021-02-20      AUD    1.2723
# 11213  2021-02-20      EUR    0.8238
# 11214  2021-02-20      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
#3.Products
import pandas as pd
try:
    df3 = pd.read_csv('/Products.csv', encoding='utf-8')
except UnicodeDecodeError:
    df3 = pd.read_csv('/Products.csv', encoding='latin1')

# %%
df3.head()
# Out:
#    ProductKey                         Product Name    Brand   Color  \
# 0           1  Contoso 512MB MP3 Player E51 Silver  Contoso  Silver
# 1           2    Contoso 512MB MP3 Player E51 Blue  Contoso    Blue
# 2           3     Contoso 1G MP3 Player E100 White  Contoso   White
# 3           4    Contoso 2G MP3 Player E200 Silver  Contoso  Silver
# 4           5       Contoso 2G MP3 Player E200 Red  Contoso     Red
#
#   Unit Cost USD Unit Price USD  SubcategoryKey Subcategory  CategoryKey  \
# 0        $6.62         $12.99              101     MP4&MP3            1
# 1        $6.62         $12.99              101     MP4&MP3            1
# 2        $7.40         $14.52              101     MP4&MP3            1
# 3       $11.00         $21.57              101     MP4&MP3            1
# 4       $11.00         $21.57              101     MP4&MP3            1
#
#   Category
# 0    Audio
# 1    Audio
# 2    Audio
# 3    Audio
# 4    Audio

# %%
#2-Data preparation:
df3.shape
# Out:
# (2517, 10)

# %%
# Check for missing values
df3.isnull().sum()
# Out:
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
# Check for duplicates
df3.duplicated().sum()
# Out:
# 0

# %%
# Check data types
df3.dtypes
# Out:
# ProductKey         int64
# Product Name      object
# Brand             object
# Color             object
# Unit Cost USD     object
# Unit Price USD    object
# SubcategoryKey     int64
# Subcategory       object
# CategoryKey        int64
# Category          object
# dtype: object

# %%
## converting dtypes using astype:
df3['Unit Cost USD']=df3['Unit Cost USD'].astype(str).str.replace('$','').str.replace(',','').astype(float)
df3['Unit Price USD']=df3['Unit Price USD'].astype(str).str.replace('$','').str.replace(',','').astype(float)

# %%
df3.dtypes
# Out:
# ProductKey          int64
# Product Name       object
# Brand              object
# Color              object
# Unit Cost USD     float64
# Unit Price USD    float64
# SubcategoryKey      int64
# Subcategory        object
# CategoryKey         int64
# Category           object
# dtype: object

# %%
df3.to_csv('Products1.csv',index=False)

# %%
pd.read_csv('Products1.csv')
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color  Unit Cost USD  Unit Price USD  SubcategoryKey  \
# ...

# %%
#4.Sales
import pandas as pd
try:
    df4 = pd.read_csv('/Sales.csv', encoding='utf-8')
except UnicodeDecodeError:
    df4 = pd.read_csv('/Sales.csv', encoding='latin1')

# %%
df4.head()
# Out:
#    Order Number  Line Item Order Date Delivery Date  CustomerKey  StoreKey  \
# 0        366000          1   1/1/2016           NaN       265598        10
# 1        366001          1   1/1/2016     1/13/2016      1269051         0
# 2        366001          2   1/1/2016     1/13/2016      1269051         0
# 3        366002          1   1/1/2016     1/12/2016       266019         0
# 4        366002          2   1/1/2016     1/12/2016       266019         0
#
#    ProductKey  Quantity Currency Code
# 0        1304         1           CAD
# 1        1048         2           USD
# 2        2007         1           USD
# 3        1106         7           CAD
# 4         373         1           CAD

# %%
df4.shape
# Out:
# (62884, 9)

# %%
df4.dtypes
# Out:
# Order Number      int64
# Line Item         int64
# Order Date       object
# Delivery Date    object
# CustomerKey       int64
# StoreKey          int64
# ProductKey        int64
# Quantity          int64
# Currency Code    object
# dtype: object

# %%
missing_values=df4.isnull().sum()
print(missing_values)
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
#to find missing percentage:
row_count = len(df4)
print(row_count)
missing_count=missing_values.sum()
missing_percentage=(missing_count/row_count)*100
print(missing_percentage)
# Out:
# 62884
# 79.064626932129

# %%
df4=df4.drop('Delivery Date',axis=1)

# %%
# Check data types
df4.dtypes
# Out:
# Order Number              int64
# Line Item                 int64
# Order Date       datetime64[ns]
# CustomerKey               int64
# StoreKey                  int64
# ProductKey                int64
# Quantity                  int64
# Currency Code            object
# dtype: object

# %%
df4['Order Date']=pd.to_datetime(df4['Order Date'],errors='coerce')

# %%
# Check data types
df4.dtypes
# Out:
# Order Number              int64
# Line Item                 int64
# Order Date       datetime64[ns]
# CustomerKey               int64
# StoreKey                  int64
# ProductKey                int64
# Quantity                  int64
# Currency Code            object
# dtype: object

# %%
#Box Plot to detect outliers
import seaborn as sns
sns.boxplot(df4['Quantity'])
# Out:
# <Axes: >

# %%
#outliers been removed:
import seaborn as sns
import matplotlib.pyplot as plt
threshold=8
removed_outliers_df=df4[df4['Quantity']<=threshold]
sns.boxplot(removed_outliers_df['Quantity'])
# Out:
# <Axes: >

# %%
removed_outliers_df.to_csv('Sales1.csv',index=False)

# %%
pd.read_csv('Sales1.csv')
# Out:
#        Order Number  Line Item  Order Date  CustomerKey  StoreKey  ProductKey  \
# 0            366000          1  2016-01-01       265598        10        1304
# 1            366001          1  2016-01-01      1269051         0        1048
# 2            366001          2  2016-01-01      1269051         0        2007
# 3            366002          1  2016-01-01       266019         0        1106
# 4            366002          2  2016-01-01       266019         0         373
# ...             ...        ...         ...          ...       ...         ...
# 61071       2243030          1  2021-02-20      1216913        43         632
# 61072       2243031          1  2021-02-20       511229         0          98
# 61073       2243032          1  2021-02-20       331277         0        1613
# 61074       2243032          2  2021-02-20       331277         0        1717
# 61075       2243032          3  2021-02-20       331277         0         464
#
#        Quantity Currency Code
# ...

# %%
#5.Stores.csv
import pandas as pd
try:
    df5 = pd.read_csv('/Stores.csv', encoding='utf-8')
except UnicodeDecodeError:
    df5 = pd.read_csv('/Stores.csv', encoding='latin1')

# %%
df5.head()
# Out:
#    StoreKey    Country                         State  Square Meters  Open Date
# 0         1  Australia  Australian Capital Territory          595.0   1/1/2008
# 1         2  Australia            Northern Territory          665.0  1/12/2008
# 2         3  Australia               South Australia         2000.0   1/7/2012
# 3         4  Australia                      Tasmania         2000.0   1/1/2010
# 4         5  Australia                      Victoria         2000.0  12/9/2015

# %%
df5.shape
# Out:
# (67, 5)

# %%
df5.dtypes
# Out:
# StoreKey           int64
# Country           object
# State             object
# Square Meters    float64
# Open Date         object
# dtype: object

# %%
df5.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    1
# Open Date        0
# dtype: int64

# %%
df5['Square Meters']=df5['Square Meters'].fillna(value=0)

# %%
#df5=df5.dropna(subset=['Square Meters'],axis=0)

# %%
df5.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    0
# Open Date        0
# dtype: int64

# %%
df5
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            0.0
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# ...

# %%
df5['Open Date']=pd.to_datetime(df5['Open Date'],errors='coerce')

# %%
df5.dtypes
# Out:
# StoreKey                  int64
# Country                  object
# State                    object
# Square Meters           float64
# Open Date        datetime64[ns]
# dtype: object

# %%
df5.to_csv('Stores1.csv',index=False)

# %%
pd.read_csv('Stores1.csv')
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            0.0
#
#      Open Date
# 0   2008-01-01
# 1   2008-01-12
# 2   2012-01-07
# 3   2010-01-01
# ...

# %%
# sales table having the key of other tables, but in exchange table,
#we dont have any key,so we add extra column in sales table to add exchange rate to currency code according to date . 


merged_df = pd.merge(
    df4,
    df2[['Date', 'Currency', 'Exchange']],
    left_on=['Order Date', 'Currency Code'],
    right_on=['Date', 'Currency'],
    how='left'
)

# %%
merged_df
# Out:
#        Order Number  Line Item Order Date  CustomerKey  StoreKey  ProductKey  \
# 0            366000          1 2016-01-01       265598        10        1304
# 1            366001          1 2016-01-01      1269051         0        1048
# 2            366001          2 2016-01-01      1269051         0        2007
# 3            366002          1 2016-01-01       266019         0        1106
# 4            366002          2 2016-01-01       266019         0         373
# ...             ...        ...        ...          ...       ...         ...
# 62879       2243030          1 2021-02-20      1216913        43         632
# 62880       2243031          1 2021-02-20       511229         0          98
# 62881       2243032          1 2021-02-20       331277         0        1613
# 62882       2243032          2 2021-02-20       331277         0        1717
# 62883       2243032          3 2021-02-20       331277         0         464
#
# ...

# %%
# Drop the now-redundant columns
merged_df.drop(columns=['Date', 'Currency'], inplace=True)

# %%
merged_df
# Out:
#        Order Number  Line Item Order Date  CustomerKey  StoreKey  ProductKey  \
# 0            366000          1 2016-01-01       265598        10        1304
# 1            366001          1 2016-01-01      1269051         0        1048
# 2            366001          2 2016-01-01      1269051         0        2007
# 3            366002          1 2016-01-01       266019         0        1106
# 4            366002          2 2016-01-01       266019         0         373
# ...             ...        ...        ...          ...       ...         ...
# 62879       2243030          1 2021-02-20      1216913        43         632
# 62880       2243031          1 2021-02-20       511229         0          98
# 62881       2243032          1 2021-02-20       331277         0        1613
# 62882       2243032          2 2021-02-20       331277         0        1717
# 62883       2243032          3 2021-02-20       331277         0         464
#
#        Quantity Currency Code  Exchange
# ...

# %%
merged_df.to_csv('Sales_Exchange.csv',index=False)

# %%
pd.read_csv('Sales_Exchange.csv')
# Out:
#        Order Number  Line Item  Order Date  CustomerKey  StoreKey  ProductKey  \
# 0            366000          1  2016-01-01       265598        10        1304
# 1            366001          1  2016-01-01      1269051         0        1048
# 2            366001          2  2016-01-01      1269051         0        2007
# 3            366002          1  2016-01-01       266019         0        1106
# 4            366002          2  2016-01-01       266019         0         373
# ...             ...        ...         ...          ...       ...         ...
# 62879       2243030          1  2021-02-20      1216913        43         632
# 62880       2243031          1  2021-02-20       511229         0          98
# 62881       2243032          1  2021-02-20       331277         0        1613
# 62882       2243032          2  2021-02-20       331277         0        1717
# 62883       2243032          3  2021-02-20       331277         0         464
#
# ...
